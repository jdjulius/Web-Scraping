# %% [markdown]
# # Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# # Step 2 - Parameters

# %%
params = {
    'ResultOrder': 'Relevance',
    'Term': 'computers',
    'CountryCode': 'GT',
}

# %% [markdown]
# # Step 3 - Response

# %%
response = requests.get('https://www.ebooks.com/api/search/', params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'search_term': 'computers',
#  'start_record': 1,
#  'total_results': 24614,
#  'books': [{'id': 976630,
#    'book_url': '/en-gt/book/976630/computers/sergey-p-suprun/',
#    'image_url': 'https://image.ebooks.com/previews/000/000976/000976630/000976630-sml-1.jpg',
#    'image_alt_tag': 'Computers: Classical, Quantum and Others',
#    'title': 'Computers',
#    'edition': '',
#    'subtitle': 'Classical, Quantum and Others',
#    'authors': [{'author_name': 'Sergey P. Suprun',
#      'author_url': '/en-gt/author/sergey-p.-suprun/478854/'},
#     {'author_name': 'Anatoly P. Suprun',
#      'author_url': '/en-gt/author/anatoly-p.-suprun/478855/'}],
#    'num_authors': 2,
#    'series': ' Series',
#    'series_number': '',
#    'has_series': False,
#    'series_url': '',
#    'publisher': 'Bentham Science Publishers',
#    'publication_year': '2012',
#    'price': 'US$21.00',
# ...

# %%
type(response.json())
# Out:
# dict

# %% [markdown]
# # Step 4 - Output keys

# %%
response.json().keys()
# Out:
# dict_keys(['search_term', 'start_record', 'total_results', 'books', 'pages', 'previous_page', 'next_page'])

# %% [markdown]
# # Step 5 - Find your data

# %%
# title
# subtitle
# author
# publisher
# publication date
# price

# %%
response.json()['books']
# Out:
# [{'id': 976630,
#   'book_url': '/en-gt/book/976630/computers/sergey-p-suprun/',
#   'image_url': 'https://image.ebooks.com/previews/000/000976/000976630/000976630-sml-1.jpg',
#   'image_alt_tag': 'Computers: Classical, Quantum and Others',
#   'title': 'Computers',
#   'edition': '',
#   'subtitle': 'Classical, Quantum and Others',
#   'authors': [{'author_name': 'Sergey P. Suprun',
#     'author_url': '/en-gt/author/sergey-p.-suprun/478854/'},
#    {'author_name': 'Anatoly P. Suprun',
#     'author_url': '/en-gt/author/anatoly-p.-suprun/478855/'}],
#   'num_authors': 2,
#   'series': ' Series',
#   'series_number': '',
#   'has_series': False,
#   'series_url': '',
#   'publisher': 'Bentham Science Publishers',
#   'publication_year': '2012',
#   'price': 'US$21.00',
# ...

# %%
len(response.json()['books'])
# Out:
# 10

# %%
resultsJson = response.json()['books']

# %%
resultsJson[0]['title']
# Out:
# 'Computers'

# %%
resultsJson[0]['subtitle']
# Out:
# 'Classical, Quantum and Others'

# %%
resultsJson[0]['authors'][0]['author_name']
# Out:
# 'Sergey P. Suprun'

# %%
resultsJson[0]['publisher']
# Out:
# 'Bentham Science Publishers'

# %%
resultsJson[0]['publication_year']
# Out:
# '2012'

# %%
resultsJson[0]['price']
# Out:
# 'US$21.00'

# %% [markdown]
# # Step 6 - Loop

# %%
title = []
subtitle = []
author = []
publisher = []
publisher_year = []
price = []

for result in resultsJson:
    title.append(result['title'])
    subtitle.append(result['subtitle'])
    author.append(result['authors'][0]['author_name'])
    publisher.append(result['publisher'])
    publisher_year.append(result['publication_year'])
    price.append(result['price'])

# %%
title
# Out:
# ['Computers',
#  'Electronic Computers',
#  'Electronic Computers',
#  'Nursing and Computers',
#  'Nursing and Computers',
#  'Computers and Creativity',
#  'Computers and Art',
#  'Computers and Games',
#  'Computers and Games',
#  'Computers and Games']

# %% [markdown]
# # Step 7 - pandas dataframe

# %%
book_df = pd.DataFrame({'Title':title,
                        'Subtitle': subtitle,
                        'author': author,
                        'publisher': publisher,
                        'publication year': publisher_year,
                        'price': price})

# %%
book_df
# Out:
#                       Title  \
# 0                 Computers
# 1      Electronic Computers
# 2      Electronic Computers
# 3     Nursing and Computers
# 4     Nursing and Computers
# 5  Computers and Creativity
# 6         Computers and Art
# 7       Computers and Games
# 8       Computers and Games
# 9       Computers and Games
#
#                                             Subtitle                 author  \
# 0                      Classical, Quantum and Others       Sergey P. Suprun
# 1            Fundamentals, Systems, and Applications   Paul Frhr von Handel
# 2            Fundamentals, Systems, and Applications        Paul von Handel
# 3                            An Anthology, 1987–1996       Virginia K. Saba
# 4                                       An Anthology       Virginia K. Saba
# 5                                                       Ursula Fashingbauer
# 6                                  Computers and Art         Stuart Mealing
# ...

# %%
book_df.to_excel('books.xlsx', index=False)
