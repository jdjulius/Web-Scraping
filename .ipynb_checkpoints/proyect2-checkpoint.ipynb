# %% [markdown]
# # Step 1 - import

# %%
import requests
import pandas as pd

# %% [markdown]
# # Step 2 - curl

# %%
headers = {
    'authority': 'www.autolist.com',
    'accept': '*/*',
    'accept-language': 'es,es-GT;q=0.9,en-US;q=0.8,en;q=0.7,es-419;q=0.6',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzEwMy4wLjAuMCBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=c98b9673-d16b-424b-997d-befca34ad812.1656731304876; _gid=GA1.2.1640513968.1656731305; _pbjs_userid_consent_data=3524755945110770; _pubcid=df512466-438f-4d34-9e1b-d0c4251a2254; _sp_ses.8ca5=*; _fbp=fb.1.1656731305377.893996206; __gads=ID=89731f3ea892865a:T=1656731306:S=ALNI_Mbaz34xMb89Io_Y9JYpL_mk98D_lQ; __gpi=UID=0000063b44bc6288:T=1656731306:RT=1656731306:S=ALNI_MbwMgVJnONNFJVSIPqZH-PU_jjv0Q; _lr_retry_request=true; _lr_env_src_ats=false; pbjs-unifiedid=%7B%22TDID%22%3A%22b3b0f675-160e-4ae2-af2f-d986f8b6a83e%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222022-06-02T03%3A08%3A28%22%7D; panoramaId_expiry=1656817708895; _cc_id=6add5b1809087998e23e3735be9a2ac8; cto_bidid=GbXF5l9Ma0dJaFEyS3pDRWFySGVTTm5oWW1sM1k4a1lsWnMlMkJhMEpBb2Y1JTJCRjRXUWRQT0dHMU9rJTJCcDV5OWtoNk4yeklwQmRvYlBGOEZDUTRYMDlGcnJYeEttWWZFVlhZMXhUYVJabjN2MWslMkJ3RFNjJTNE; _ga_KKZ1EQJKEV=GS1.1.1656731305.1.1.1656731318.0; sp-nuid=39f987bf-de3c-4341-894c-5e53a112c339; _gcl_au=1.1.1480457477.1656731320; AMP_TOKEN=%24NOT_FOUND; _ga=GA1.2.788629316.1656731305; cto_bundle=yJuu4V9VJTJCZ0tBN3VBTFJwN1ExYWRPRXJPU3clMkZDbHlzSGRJZEg5ZWVQcmglMkZwMmhrRzRwSUdLSHZxZSUyRmtOaHRxU2dKVSUyRjZwJTJCYTVVJTJGMGFJbiUyRnNkZzJiUCUyQkN1NE1pVG1SV050bTZVQllMaTklMkZ2cEc3Qjkzcjg0dzg1SDdtOEJhZ1VOdnZsaE5Ya0s2VTFkR1pwZWU0R3V5RHJHUSUzRCUzRA; _sp_id.8ca5=b5b81c0e-b961-426b-88d3-e82f2bdea0ec.1656731305.1.1656731444.1656731305.f164d6c6-81ed-49e5-b940-63635f3b202e',
    'referer': 'https://www.autolist.com/listings',
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    'x-autolist-session-guid': '8493f3c5-33cb-4ef8-80b8-4d9a62c2955a',
    'x-requested-with': 'XMLHttpRequest',
}

params = (
    ('make', 'Tesla'),
    ('model', 'Model 3'),
    ('location', 'San Lucas Sacatep\xE9quez, Sacatep\xE9quez'),
    ('latitude', '14.6147338'),
    ('longitude', '-90.6691609'),
    ('radius', '50'),
    ('page', '1'),
)

# %% [markdown]
# # Step 3 - status code

# %%
response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'total_results_count': 59,
#  'make_model_name': 'Tesla Model 3',
#  'trims': ['Base',
#   'Long Range',
#   'Mid Range',
#   'Performance',
#   'Standard',
#   'Standard Range',
#   'Standard Range Plus'],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla/Model_3',
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=14.6147338&location=San+Lucas+Sacatep%C3%A9quez%2C+Sacatep%C3%A9quez&longitude=-90.6691609&make=Tesla&model=Model+3&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1656540996,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA9NF243644',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA9NF243644',
# ...

# %%
type(response.json())
# Out:
# dict

# %% [markdown]
# # Step 4 - create json

# %%
response.json().keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %%
json = response.json()['search_results']

# %%
json
# Out:
# [{'available_nationwide': False,
#   'created_at': 1656540996,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EA9NF243644',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA9NF243644',
#   'clickoff_url': 'https://www.carmax.com/car/23029896?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 245994876,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23029896/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--d63PAwRc--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23029896/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 34.071236,
#   'lon': -117.560402,
#   'year': 2022,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$59,998',
#   'price_unformatted': 59998,
#   'mileage': '23 Miles',
# ...

# %%
len(json)
# Out:
# 20

# %% [markdown]
# # Step 5 - output keys

# %%
# model
# mileage
# year
# dealer name
# price

# %%
json[0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1656540996,
#  'recent_price_drop': None,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EA9NF243644',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EA9NF243644',
#  'clickoff_url': 'https://www.carmax.com/car/23029896?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 245994876,
#  'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23029896/1.jpg?width=1024&watermark=LYCG_1a',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--d63PAwRc--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23029896/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#  'lat': 34.071236,
#  'lon': -117.560402,
#  'year': 2022,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$59,998',
#  'price_unformatted': 59998,
#  'mileage': '23 Miles',
# ...

# %% [markdown]
# # Step 6 - find data

# %%
json[0]['model']
# Out:
# 'Model 3'

# %%
json[0]['mileage']
# Out:
# '23 Miles'

# %%
json[0]['year']
# Out:
# 2022

# %%
json[0]['dealer_name']
# Out:
# 'CarMax Ontario - Now Offering Curbside Pickup And Home Delivery'

# %%
json[0]['price']
# Out:
# '$59,998'

# %% [markdown]
# # Step 7 - Loop

# %%
model = []
mileage = []
year = []
dealerName = []
price = []

for result in json:
    model.append(result['model'])
    mileage.append(result['mileage'])
    year.append(result['year'])
    dealerName.append(result['dealer_name'])
    price.append(result['price'])

# %% [markdown]
# # Step 8 - pandas

# %%
tesla = pd.DataFrame({
    'Model':model,
    'Mileage':mileage,
    'Year':year,
    'Dealer name':dealerName,
    'price':price
})

# %%
tesla
# Out:
#       Model       Mileage  Year  \
# 0   Model 3      23 Miles  2022
# 1   Model 3      29 Miles  2022
# 2   Model 3  27,499 Miles  2018
# 3   Model 3  14,160 Miles  2021
# 4   Model 3      24 Miles  2022
# 5   Model 3  23,046 Miles  2018
# 6   Model 3  33,332 Miles  2019
# 7   Model 3   2,248 Miles  2022
# 8   Model 3      38 Miles  2022
# 9   Model 3  26,688 Miles  2019
# 10  Model 3      29 Miles  2022
# 11  Model 3   3,308 Miles  2022
# 12  Model 3  28,559 Miles  2019
# 13  Model 3      29 Miles  2022
# 14  Model 3      25 Miles  2022
# 15  Model 3      29 Miles  2022
# 16  Model 3  28,295 Miles  2021
# 17  Model 3   2,151 Miles  2022
# 18  Model 3   7,766 Miles  2021
# 19  Model 3   1,248 Miles  2022
#
#                                           Dealer name    price
# 0   CarMax Ontario - Now Offering Curbside Pickup ...  $59,998
# 1   CarMax San Gabriel Valley/Duarte - Now Offerin...  $57,998
# 2   CarMax Henderson - Now Offering Curbside Picku...  $51,998
# ...

# %%
tesla.to_excel('tesla.xlsx', index=False)

# %% [markdown]
# # Step 9 - Scraping multiple pages

# %%
headers = {
    'authority': 'www.autolist.com',
    'accept': '*/*',
    'accept-language': 'es,es-GT;q=0.9,en-US;q=0.8,en;q=0.7,es-419;q=0.6',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzEwMy4wLjAuMCBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=c98b9673-d16b-424b-997d-befca34ad812.1656731304876; _gid=GA1.2.1640513968.1656731305; _pbjs_userid_consent_data=3524755945110770; _pubcid=df512466-438f-4d34-9e1b-d0c4251a2254; _sp_ses.8ca5=*; _fbp=fb.1.1656731305377.893996206; __gads=ID=89731f3ea892865a:T=1656731306:S=ALNI_Mbaz34xMb89Io_Y9JYpL_mk98D_lQ; __gpi=UID=0000063b44bc6288:T=1656731306:RT=1656731306:S=ALNI_MbwMgVJnONNFJVSIPqZH-PU_jjv0Q; _lr_retry_request=true; _lr_env_src_ats=false; pbjs-unifiedid=%7B%22TDID%22%3A%22b3b0f675-160e-4ae2-af2f-d986f8b6a83e%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222022-06-02T03%3A08%3A28%22%7D; panoramaId_expiry=1656817708895; _cc_id=6add5b1809087998e23e3735be9a2ac8; cto_bidid=GbXF5l9Ma0dJaFEyS3pDRWFySGVTTm5oWW1sM1k4a1lsWnMlMkJhMEpBb2Y1JTJCRjRXUWRQT0dHMU9rJTJCcDV5OWtoNk4yeklwQmRvYlBGOEZDUTRYMDlGcnJYeEttWWZFVlhZMXhUYVJabjN2MWslMkJ3RFNjJTNE; _ga_KKZ1EQJKEV=GS1.1.1656731305.1.1.1656731318.0; sp-nuid=39f987bf-de3c-4341-894c-5e53a112c339; _gcl_au=1.1.1480457477.1656731320; AMP_TOKEN=%24NOT_FOUND; _ga=GA1.2.788629316.1656731305; cto_bundle=yJuu4V9VJTJCZ0tBN3VBTFJwN1ExYWRPRXJPU3clMkZDbHlzSGRJZEg5ZWVQcmglMkZwMmhrRzRwSUdLSHZxZSUyRmtOaHRxU2dKVSUyRjZwJTJCYTVVJTJGMGFJbiUyRnNkZzJiUCUyQkN1NE1pVG1SV050bTZVQllMaTklMkZ2cEc3Qjkzcjg0dzg1SDdtOEJhZ1VOdnZsaE5Ya0s2VTFkR1pwZWU0R3V5RHJHUSUzRCUzRA; _sp_id.8ca5=b5b81c0e-b961-426b-88d3-e82f2bdea0ec.1656731305.1.1656731444.1656731305.f164d6c6-81ed-49e5-b940-63635f3b202e',
    'referer': 'https://www.autolist.com/listings',
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    'x-autolist-session-guid': '8493f3c5-33cb-4ef8-80b8-4d9a62c2955a',
    'x-requested-with': 'XMLHttpRequest',
}

model = []
mileage = []
year = []
dealerName = []
price = []

for i  in range(1,6):
    params = (
        ('make', 'Tesla'),
        ('model', 'Model 3'),
        ('location', 'San Lucas Sacatep\xE9quez, Sacatep\xE9quez'),
        ('latitude', '14.6147338'),
        ('longitude', '-90.6691609'),
        ('radius', '50'),
        ('page', str(i)),
    )
    
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    json = response.json()['search_results']
    

    for result in json:
        model.append(result['model'])
        mileage.append(result['mileage'])
        year.append(result['year'])
        dealerName.append(result['dealer_name'])
        price.append(result['price'])

# %%
tesla_multiple = pd.DataFrame({
    'Model':model,
    'Mileage':mileage,
    'Year':year,
    'Dealer name':dealerName,
    'price':price
})

# %%
tesla_multiple
# Out:
#       Model       Mileage  Year  \
# 0   Model 3      23 Miles  2022
# 1   Model 3      29 Miles  2022
# 2   Model 3  27,499 Miles  2018
# 3   Model 3  14,160 Miles  2021
# 4   Model 3      24 Miles  2022
# 5   Model 3  23,046 Miles  2018
# 6   Model 3  33,332 Miles  2019
# 7   Model 3   2,248 Miles  2022
# 8   Model 3      38 Miles  2022
# 9   Model 3  26,688 Miles  2019
# 10  Model 3      29 Miles  2022
# 11  Model 3   3,308 Miles  2022
# 12  Model 3  28,559 Miles  2019
# 13  Model 3      29 Miles  2022
# 14  Model 3      25 Miles  2022
# 15  Model 3      29 Miles  2022
# 16  Model 3  28,295 Miles  2021
# 17  Model 3   2,151 Miles  2022
# 18  Model 3   7,766 Miles  2021
# 19  Model 3   1,248 Miles  2022
# 20  Model 3   3,884 Miles  2022
# 21  Model 3   7,727 Miles  2022
# 22  Model 3      29 Miles  2022
# 23  Model 3  12,860 Miles  2021
# 24  Model 3  19,039 Miles  2021
# 25  Model 3      25 Miles  2022
# 26  Model 3  18,647 Miles  2019
# 27  Model 3   7,264 Miles  2021
# ...

# %%
tesla_multiple.to_excel('tesl_multiple.xlsx', index=False)
